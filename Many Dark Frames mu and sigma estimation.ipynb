# %%
import astropy
import matplotlib.pyplot as plt
from astropy.io import fits
import numpy as np
from scipy.stats import norm
import matplotlib.mlab as mlab
import glob
from scipy import ndimage
from scipy.optimize import curve_fit
from astropy.modeling.models import Linear1D
from astropy.table import Table

# %%
list_of_means = []
mean_error = []

list_of_exposure_times = [0.1, 0.2, 0.5, 1, 2, 5, 10, 20, 30, 40, 50, 100, 150, 200, 300, 600]

list_of_std = []
std_error = []




#exposure time: 0.1 seconds
point1s = []
point1s.append('/Users/arianna/Dark_010.fits')

for file in glob.glob('/Users/arianna/Dark_00[1-9].fits'):
    point1s.append(file)

data = []
for i in point1s:
    point1s_data = fits.open(i)
    point1s_data = point1s_data[0].data
    data.append(point1s_data)
    
list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)





#exposure time: 0.2 seconds
point2s = []
point2s.append('/Users/arianna/Dark_020.fits')

for file in glob.glob('/Users/arianna/Dark_01[1-9].fits'):
    point2s.append(file)

data = []
for i in point2s:
    point2s_data = fits.open(i)
    point2s_data = point2s_data[0].data
    data.append(point2s_data)
    
list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)




#exposure time: 0.5 seconds
point5s = []
point5s.append('/Users/arianna/Dark_030.fits')

for file in glob.glob('/Users/arianna/Dark_02[1-9].fits'):
    point5s.append(file)

data = []
for i in point5s:
    point5s_data = fits.open(i)
    point5s_data = point5s_data[0].data
    data.append(point5s_data)
    
list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)





#exposure time: 1 seconds
one_s = []
one_s.append('/Users/arianna/Dark_040.fits')

for file in glob.glob('/Users/arianna/Dark_03[1-9].fits'):
    one_s.append(file)

data = []
for i in one_s:
    one_s_data = fits.open(i)
    one_s_data = one_s_data[0].data
    data.append(one_s_data)
    
list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)





#exposure time: 2 seconds
two_s = []
two_s.append('/Users/arianna/Dark_050.fits')

for file in glob.glob('/Users/arianna/Dark_04[1-9].fits'):
    two_s.append(file)

data = []
for i in two_s:
    two_s_data = fits.open(i)
    two_s_data = two_s_data[0].data
    data.append(two_s_data)
    
list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)





#exposure time: 5 seconds
five_s = []
five_s.append('/Users/arianna/Dark_060.fits')

for file in glob.glob('/Users/arianna/Dark_05[1-9].fits'):
    five_s.append(file)
    
data = []
for i in five_s:
    five_s_data = fits.open(i)
    five_s_data = five_s_data[0].data
    data.append(five_s_data)
    
list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)






#exposure time: 10 seconds
ten_s = []
ten_s.append('/Users/arianna/Dark_070.fits')

for file in glob.glob('/Users/arianna/Dark_06[1-9].fits'):
    ten_s.append(file)

data = []
for i in ten_s:
    ten_s_data = fits.open(i)
    ten_s_data = ten_s_data[0].data
    data.append(ten_s_data)
    
list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)






#exposure time: 20 seconds
twenty_s = []
twenty_s.append('/Users/arianna/Dark_080.fits')

for file in glob.glob('/Users/arianna/Dark_07[1-9].fits'):
    twenty_s.append(file)

data = []
for i in twenty_s:
    twenty_s_data = fits.open(i)
    twenty_s_data = twenty_s_data[0].data
    data.append(twenty_s_data)
    
list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)






#exposure time: 30 seconds
thirty_s = []
thirty_s.append('/Users/arianna/Dark_090.fits')

for file in glob.glob('/Users/arianna/Dark_08[1-9].fits'):
    thirty_s.append(file)

data = []
for i in thirty_s:
    thirty_s_data = fits.open(i)
    thirty_s_data = thirty_s_data[0].data
    data.append(thirty_s_data)
    
list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)





#exposure time: 40 seconds
forty_s = []
forty_s.append('/Users/arianna/Dark_100.fits')

for file in glob.glob('/Users/arianna/Dark_09[1-9].fits'):
    forty_s.append(file)

data = []
for i in forty_s:
    forty_s_data = fits.open(i)
    forty_s_data = forty_s_data[0].data
    data.append(forty_s_data)
    
list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)





#exposure time: 50 seconds
fifty_s = []
fifty_s.append('/Users/arianna/Dark_110.fits')

for file in glob.glob('/Users/arianna/Dark_10[1-9].fits'):
    fifty_s.append(file)

data = []
for i in fifty_s:
    fifty_s_data = fits.open(i)
    fifty_s_data = fifty_s_data[0].data
    data.append(fifty_s_data)
    
list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)





#exposure time: 100 seconds
one_hundred_s = []
one_hundred_s.append('/Users/arianna/Dark_120.fits')

for file in glob.glob('/Users/arianna/Dark_11[1-9].fits'):
    one_hundred_s.append(file)

data = []
for i in one_hundred_s:
    one_hundred_s_data = fits.open(i)
    one_hundred_s_data = one_hundred_s_data[0].data
    data.append(one_hundred_s_data)
    
list_of_means.append(np.mean(data)) 

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)





#exposure time: 150 seconds
one_hundred_fifty_s = []
one_hundred_fifty_s.append('/Users/arianna/Dark_130.fits')

for file in glob.glob('/Users/arianna/Dark_12[1-9].fits'):
    one_hundred_fifty_s.append(file)

data = []
for i in one_hundred_fifty_s:
    one_hundred_fifty_s_data = fits.open(i)
    one_hundred_fifty_s_data = one_hundred_fifty_s_data[0].data
    data.append(one_hundred_fifty_s_data)
    
list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)





#exposure time: 200 seconds
two_hundred_s = []
two_hundred_s.append('/Users/arianna/Dark_140.fits')

for file in glob.glob('/Users/arianna/Dark_13[1-9].fits'):
    two_hundred_s.append(file)
    
data = []
for i in two_hundred_s:
    two_hundred_s_data = fits.open(i)
    two_hundred_s_data = two_hundred_s_data[0].data
    data.append(two_hundred_s_data)
    
list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)






#exposure time: 300 seconds
three_hundred_s = []
three_hundred_s.append('/Users/arianna/Dark_150.fits')

for file in glob.glob('/Users/arianna/Dark_14[1-9].fits'):
    three_hundred_s.append(file)
    
data = []   
for i in three_hundred_s:
    three_hundred_s_data = fits.open(i)
    three_hundred_s_data = three_hundred_s_data[0].data
    data.append(three_hundred_s_data)
    
list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)





#exposure time: 600 seconds
six_hundred_s = []
#six_hundred_s.append('/Users/arianna/Dark_160.fits')

for file in glob.glob('/Users/arianna/Dark_15[1-5].fits'):
    six_hundred_s.append(file)
    
data = []
for i in six_hundred_s:
    six_hundred_s_data = fits.open(i)
    six_hundred_s_data = six_hundred_s_data[0].data
    
    data.append(six_hundred_s_data)

list_of_means.append(np.mean(data))

list_of_std.append(np.std(data))

m_error = np.std(data)/np.sqrt(np.size(data))
mean_error.append(m_error)




#table of results
a = list_of_exposure_times
b = list_of_means
c = mean_error
d = list_of_std
#e = std_error

t = Table([a, b, c, d], names=('Exposure Time', 'Mean', 'Error in mean', 'Stand. Dev.'))
print(t)
# Out:
# Exposure Time        Mean           Error in mean        Stand. Dev.
# ------------- ----------------- --------------------- ------------------
#           0.1 924.8971830065359 0.0016855242637751492  6.658567551294263
#           0.2 925.4495019223376 0.0016849341723015451  6.656236428555256
#           0.5 925.5517660515186 0.0016920681501027264  6.684418801315768
#           1.0 925.9255911188004 0.0017225711769857993  6.804919270745367
#           2.0  925.884454312444 0.0017775147456734056 7.0219707077838365
#           5.0 926.0042970011534 0.0019037300042230234  7.520576894071768
#          10.0 925.8330163398692 0.0024000208848650906  9.481145735985134
#          20.0 925.9786733948481 0.0032952335073771874 13.017632185855232
#          30.0 926.8110225554274  0.005037810317459982   19.9015825700919
#          40.0 927.0234474561066 0.0065578973594839374  25.90659980460726
#          50.0 927.5438535178778  0.007815699992218999  30.87547742699397
# ...

# %%
ydata = np.array(list_of_means)
xdata = np.array(list_of_exposure_times)

# %matplotlib notebook
# plot of means vs exposure time
plt.figure()
plt.errorbar(xdata, ydata, yerr=mean_error, fmt='.', label = 'Data', ecolor = 'r')
plt.xlabel('Exposure time t (s)', fontsize=10)
plt.ylabel('Mean $\mu$ (pixel value)', fontsize=10)
plt.title('Plot of mean vs exposure time', fontsize=10)
plt.legend(prop={'size': 10}, loc='upper left')
plt.show()


# plot of means vs exposure time with logarithmic x-axis
plt.figure()
plt.semilogx(xdata, ydata, '.', color = 'b')
plt.errorbar(xdata, ydata, yerr=mean_error, fmt='.', label = 'Data', ecolor = 'red')
plt.xlabel('Exposure time t (s)', fontsize=10)
plt.ylabel('Mean $\mu$ (pixel value)', fontsize=10)
plt.title('Plot of mean vs exposure time', fontsize=10)
plt.legend(prop={'size': 10}, loc='upper left')
plt.show()

# curve fit second plot
x_new = np.linspace(0, 600, 5)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
sdata = np.array(list_of_std)
xdata = np.array(list_of_exposure_times)

# %matplotlib notebook
# plot of standard deviation vs exposure time
plt.figure()
plt.plot(xdata, sdata, '.', label = 'Data') #yerr = std_error,
plt.xlabel('Exposure time t (s)', fontsize=10)
plt.ylabel('Standard Deviation $\sigma$ (pixel value)', fontsize=10)
plt.title('Plot of standard deviation vs exposure time', fontsize=10)
plt.legend(prop={'size': 10}, loc='upper left')
plt.show()


# plot of standard deviation vs exposure time with logarithmic x axis
plt.figure()
plt.semilogx(xdata, sdata, '.', label = 'Data')
#plt.errorbar(xdata, sdata, yerr=std_error, fmt='o', label = 'Data', color = 'b')
plt.xlabel('Exposure time t (s)', fontsize=10)
plt.ylabel('Standard Deviation $\sigma$ (pixel value)', fontsize=10)
plt.title('Plot of standard deviation vs exposure time', fontsize=10)
plt.legend(prop={'size': 10}, loc='upper left')
plt.show()


# plot of standard deviation vs exposure time with logarithmic y axis
plt.figure()
plt.semilogy(xdata, sdata, '.', label = 'Data')
#plt.errorbar(xdata, sdata, yerr=std_error, fmt='o', label = 'Data', color = 'b')
plt.xlabel('Exposure time t (s)', fontsize=10)
plt.ylabel('Standard Deviation $\sigma$ (pixel value)', fontsize=10)
plt.title('Plot of standard deviation vs exposure time', fontsize=10)
plt.legend(prop={'size': 10}, loc='upper left')
plt.show()

# curve fit first graph
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Data from dark frames:
#
# For each exposure time, (I believe) ten frames have been taken. (Must check this carefully).
#
# For each set of frames taken with the same exposure time, I grouped the 10 sets of data together and I took the mean pixel value averaged over all the ten pictures.
#
# Then I calculated the standard deviation of this data using np.std, which I believe uses the formula we need. (Check on the numpy library).
#
# The error in the mean was calculated by dividing the standard deviation by the square root of the number of pixels (this number was found with np.size). np.size does xsize times ysize times number of arrays in the main data array (1530 x 1020 x 10).
#
#
# IMPORTANT!!
# Now must find how to calculated the error in sigma.
